# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

from time import time
import math
import ipython_memory_usage as imu
imu.start_watching_memory()
# Out:
# In [2] used 0.0000 MiB RAM in 0.10s, peaked 0.00 MiB above current, total RAM usage 53.99 MiB

# %%
# coroutine.py
#
# A decorator function that takes care of starting a coroutine
# automatically on call.

def coroutine(func):
    def start(*args,**kwargs):
        cr = func(*args,**kwargs)
        cr.next()
        return cr
    return start

# Example use
if __name__ == '__main__':
    @coroutine
    def grep(pattern):
        print "Looking for %s" % pattern
        while True:
            line = (yield)
            if pattern in line:
                print line,

    g = grep("python")
    # Notice how you don't need a next() call here
    g.send("Yeah, but no, but yeah, but no")
    g.send("A series of tubes")
    g.send("python generators rock!")
    print type(g)
# Out:
# Looking for python
# python generators rock! <type 'generator'>
# In [3] used 0.0820 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 54.07 MiB

# %%
## A co-routine that acts as a sink - collects the items it recieves as input into a global-scope array
## Can you figure out how to assign the collector the storage array ? I can't...
@coroutine
def collector(O):
    while True:
        item=(yield)
        O.append(item)
# Out:
# In [4] used 0.0117 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 54.09 MiB

# %% [markdown]
# ### Estimating the average

# %%
@coroutine
def av_filter(target,alpha=0):
    t=0; s=0
    while True:
        a=(yield) # wait here to be get something sent.
        if(alpha==0):  # regular average
            t+=1
            alpha_=1.0/t
            s=alpha_*a+(1-alpha_)*s
        else:  # Exponentially decaying average
            s=alpha*a+(1-alpha)*s
        r=a-s  # a: input, s/n: average, r: residual
        target.send((a,s,r))
# Out:
# In [14] used 0.0156 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 68.99 MiB

# %%
sz=1000; scale=100.0
a=np.random.normal(loc=0,scale=1,size=sz) 
a= a+3*np.sin(np.arange(0,sz/scale,1/scale))
print len(a)

## 0 regular average; 1: no smoothing; 0.1 too large,  0.01 too small, 0.03 pretty good.
G=[]
Av=av_filter(collector(G),alpha=0.1)
for x in a:
    Av.send(x)

print len(G)
# Out:
# 1000
# 1000
# In [27] used 0.0000 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 89.94 MiB

# %%
A=[]; AV=[]; R=[]
for (a,av,r) in G:
    A.append(a)
    AV.append(av)
    R.append(r)
# Out:
# In [25] used 0.0000 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 84.48 MiB

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
plt.plot(A,label='input')
plt.plot(AV,linewidth=3.0,label='average')
plt.plot(R,label='residual')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
# Out:
# In [26] used 5.4570 MiB RAM in 0.41s, peaked 0.00 MiB above current, total RAM usage 89.94 MiB

# %% [markdown]
# **Suggested work**
#
# * Try different values of alpha
# * Try using different types of signal (fixed mean, square wave, saw-tooth)

# %% [markdown]
# ### Estimating the standard deviation

# %%
# This coroutine assumes that the input it recieves has mean zero
@coroutine
def std_filter(target,alpha=0):
    n=0; s=0
    while True:
        (a,av,r)=(yield) # wait here to be get something sent.
        if(alpha==0):  # regular average
            n+=1
            s+=r*r
            std=math.sqrt(s/n)
            sr=r/std  # a: input, sqrt(s/n): std, sr: rescaled residual
            target.send((a,av,r,std,sr))
        else:  # Exponentially decaying average
            s=alpha*(r*r)+(1-alpha)*s
            std=math.sqrt(s)
            sr=r/std
            target.send((a,av,r,std,sr))
# Out:
# In [28] used 0.0000 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 89.94 MiB

# %%
sz=1000; scale=100.0
a=np.random.normal(loc=0,scale=1,size=sz) 
a= a+3*np.sin(np.arange(0,sz/scale,1/scale))
print len(a)

## 0.1 too large,  0.01 too small, 0.03 pretty good.
G=[]
Std=std_filter(collector(G),alpha=0.01)
Av=av_filter(Std,alpha=0.1)

for x in a:
    Av.send(x)

print len(G)
# Out:
# 1000
# 1000
# In [29] used 0.0195 MiB RAM in 0.12s, peaked 0.00 MiB above current, total RAM usage 89.96 MiB

# %%
A=[]; AV=[]; R=[]; STD=[]; SR=[];
for (a,av,r,std,sr) in G:
    A.append(a)
    AV.append(av)
    R.append(r)
    STD.append(std)
    SR.append(sr)
# Out:
# In [30] used 0.0156 MiB RAM in 0.11s, peaked 0.00 MiB above current, total RAM usage 89.97 MiB

# %%
plt.figure(num=None, figsize=(10, 8), dpi=80, facecolor='w', edgecolor='k')
plt.plot(A,label='input')
plt.plot(AV,linewidth=3.0,label='average')
#plt.plot(R,label='residual')
plt.plot(STD,label='std')
#plt.plot(SR,label='scaled residual')
plt.legend(bbox_to_anchor=(1.05, 1), loc=2, borderaxespad=0.)
plt.grid()
# Out:
# In [31] used 4.2891 MiB RAM in 0.39s, peaked 0.00 MiB above current, total RAM usage 94.26 MiB

# %% [markdown]
# **Suggested work**
#
# Leave the mean as it is and vary the standard deviation using a square wave. Observe what settings of alpha are needed for the average and for the std estimators.
