# %% [markdown]
# # Comparing the speed of python, cython and numpy
#
# first, we define two random vectors

# %%
import numpy as np
# %time
L = 1000000
a=np.random.uniform(low=-1,high=1,size=L)
b=np.random.uniform(low=-1,high=1,size=L)
# Out:
# CPU times: user 2 µs, sys: 1 µs, total: 3 µs
# Wall time: 5.01 µs

# %%
np.shape(a),np.shape(b)
# Out:
# ((1000000,), (1000000,))

# %%
a[:5],b[:5]
# Out:
# (array([ 0.30161729,  0.66075109,  0.21432004,  0.05757061, -0.0196098 ]),
#  array([-0.56663034, -0.90362467, -0.06754208,  0.58005775, -0.69716965]))

# %% [markdown]
# Check time for performing the dot product between lists rather than ndarrays.

# %% [markdown]
# ## Computing a dot product using pure python

# %%
def python_dot(a,b):
    sum=0
    for i in xrange(len(a)):
        sum+=a[i]*b[i]
    return sum

# %%
# %time python_dot(a,b)
# Out:
# CPU times: user 312 ms, sys: 11.3 ms, total: 324 ms
# Wall time: 305 ms
# 337.11597625145117

# %% [markdown]
# ## Computing the dot product using the dot method in numpy

# %%
# %time np.dot(a,b)
# Out:
# CPU times: user 1.34 ms, sys: 373 µs, total: 1.71 ms
# Wall time: 1.18 ms
# 147.03015828970382

# %% [markdown]
# ## Computing the dot product using cython

# %%
# %load_ext Cython

# %%
# %%cython
# cimport numpy as np  # makes numpy available to cython
# # The following line defines a and b as numpy arrays, cython knows how to deal with those.
# def cython_dot(np.ndarray[np.float64_t, ndim=1] a,
#                 np.ndarray[np.float64_t, ndim=1] b):
#     cdef double sum
#     cdef long i
#     sum=0
#     for i in xrange(a.shape[0]):
#         sum=sum+a[i]*b[i]
#     return sum

# %%
# %%time
cython_dot(a,b)
# Out:
# CPU times: user 2.25 ms, sys: 0 ns, total: 2.25 ms
# Wall time: 2.04 ms
# 337.1159762514512
